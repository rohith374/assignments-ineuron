# %% [markdown]
# # 1. Use examples to explain the sorting algorithms

# %% [markdown]
# * Sorting Algorithms are methods of reorganizing a large number of items into some specific order such as highest to lowest, or vice-versa, or even in some alphabetical order.

# %% [markdown]
# ####  Some of the most common sorting algorithms are:
#
# * Selection Sort
# * Bubble Sort
# * Insertion Sort
# * Merge Sort
# * Quick Sort
# * Heap Sort
# * Counting Sort
# * Radix Sort
# * Bucket Sort

# %% [markdown]
# ###### SELECTION SORT :

# %% [markdown]
# * Selection sort is a sorting algorithm that selects the smallest element from an unsorted list in each iteration and places that element at the beginning of the unsorted list.
# * **APPLICATIONS**
# * The selection sort is used when
#
#  * a small list is to be sorted,
#  * cost of swapping does not matter,
#  * checking of all the elements is compulsory

# %%
def selection_sort(L):
    for i in range(len(L)-1):
        min_index = i
        for j in range(i+1, len(L)-1):
            if L[j] < L[min_index]:
                min_index = j
        L[i], L[min_index] = L[min_index], L[i]

# %%
L = [3, 1, 41, 59, 26, 53, 59,59.456,96.335,45.89,41.000656586688554955588555,999852123.00003333,999852123.00000333,0.66995580001545,]
print(len(L))
selection_sort(L)
print(L)
# %timeit selection_sort(L)
# Out:
# 14
# [1, 3, 26, 41, 41.00065658668856, 45.89, 53, 59, 59, 59.456, 96.335, 999852123.0000033, 999852123.0000334, 0.66995580001545]
# 14.6 µs ± 565 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
M=[0.001,0.157,-0000.355445544,18,16,154,198555,3333238566,55888,191,-0.000000647893,54,89,77,-8889,6664,-157546578,99,.0141541,93479,888,11546383,6485549]
print(len(M))
selection_sort(M)
print(M)
# %timeit selection_sort(M)
# Out:
# 23
# [-157546578, -8889, -0.355445544, -6.47893e-07, 0.001, 0.0141541, 0.157, 16, 18, 54, 77, 89, 99, 154, 191, 888, 6664, 55888, 93479, 198555, 11546383, 3333238566, 6485549]
# 31.1 µs ± 1.02 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# #### BUBBLE SORT :

# %% [markdown]
# * Bubble sort is a sorting algorithm that compares two adjacent elements and swaps them until they are not in the intended order.
# * **APPLICATIONS**
#  * Bubble sort is used if
#      * complexity does not matter
#      * short and simple code is preferred

# %%
def bubble_sort(our_list):
    # We go through the list as many times as there are elements
    for i in range(len(our_list)):
        # We want the last pair of adjacent elements to be (n-2, n-1)
        for j in range(len(our_list) - 1):
            if our_list[j] > our_list[j+1]:
                # Swap
                our_list[j], our_list[j+1] = our_list[j+1], our_list[j]

# %%
b=[13,6,-8,45,33,11,1.2,-0.8]

# %%
our_list = [19, 13, 6, 2, 18, 8]
print(len(our_list))
bubble_sort(our_list)
print(our_list)
# %timeit bubble_sort(our_list)
# Out:
# 6
# [2, 6, 8, 13, 18, 19]
# 5.53 µs ± 24.9 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
print(len(b))
bubble_sort(b)
print(b)
# %timeit bubble_sort(b)
# Out:
# 8
# [-8, -0.8, 1.2, 6, 11, 13, 33, 45]
# 9.5 µs ± 384 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# #### INSERTION SORT :

# %% [markdown]
# * Insertion sort is a sorting algorithm that places an unsorted element at its suitable place in each iteration
# * In order to explain Insertion Sorting Algorithm we consider a deck of cards in which we pick a card such that we place lower card to the left and higher valued card to the right
# * **APPLICATIONS**
#     * The insertion sort is used when:
#         * the array is has a small number of elements
#         * there are only a few elements left to be sorted

# %%
def insertionSort(array):

    for step in range(1, len(array)):
        key = array[step]
        j = step - 1
        
            
        while j >= 0 and key < array[j]:
            array[j + 1] = array[j]
            j = j - 1
        
        
        array[j + 1] = key


data = [9, 5, 1, 4, 3]
insertionSort(data)
print('Sorted Array in Ascending Order:')
print(data)
# %timeit insertionSort(data)
# Out:
# Sorted Array in Ascending Order:
# [1, 3, 4, 5, 9]
# 1.32 µs ± 47.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
data = [53,53.658,99,489,567,888,0.11,0.0112,0.36491,0.00022365,448454582,9993.33524,9993.45152555675452]
insertionSort(data)
print('Sorted Array in Ascending Order:')
print(data)
# %timeit insertionSort(data)
# Out:
# Sorted Array in Ascending Order:
# [0.00022365, 0.0112, 0.11, 0.36491, 53, 53.658, 99, 489, 567, 888, 9993.33524, 9993.451525556755, 448454582]
# 3.48 µs ± 385 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# #### MERGE SORT :

# %% [markdown]
# * Merge Sort is one of the most popular sorting algorithms that is based on the principle of Divide and Conquer Algorithm,i.e. a problem is divided into multiple sub-problems. Each sub-problem is solved individually. Finally, sub-problems are combined to form the final solution.
# * **APPLICATIONS**
#        * Inversion count problem
#        * External sorting
#        * E-commerce applications

# %%
# MergeSort in Python


def mergeSort(array):
    if len(array) > 1:
       
        r = len(array)//2
        L = array[:r]
        M = array[r:]
        mergeSort(L)
        mergeSort(M)
        i = j = k = 0
        while i < len(L) and j < len(M):
            if L[i] < M[j]:
                array[k] = L[i]
                i += 1
            else:
                array[k] = M[j]
                j += 1
            k += 1
        while i < len(L):
            array[k] = L[i]
            i += 1
            k += 1
        while j < len(M):
            array[k] = M[j]
            j += 1
            k += 1
def printList(array):
    for i in range(len(array)):
        print(array[i], end=" ")
    print()


# Driver program
if __name__ == '__main__':
    array = [6, 5, 12, 10, 9, 1]

    mergeSort(array)

    print("Sorted array is: ")
    printList(array)
    # %timeit mergeSort(array)
# Out:
# Sorted array is:
# 1 5 6 9 10 12
# 8.83 µs ± 520 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
arr=[4,6,5,9,88,25,16,19,22,3635,0.99,11,45,155,1849,3325]

# %%
mergeSort(arr)

print("Sorted array is: ")
printList(arr)
# %timeit mergeSort(arr)
# Out:
# Sorted array is:
# 0.99 4 5 6 9 11 16 19 22 25 45 88 155 1849 3325 3635
# 32.5 µs ± 1.87 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# #### QUICK SORT :

# %% [markdown]
# * Quicksort is a sorting algorithm based on the divide and conquer approach.
# * An array is divided into subarrays by selecting a pivot element,i.e. it should be positioned in such a way that elements less than pivot are kept on the left side and elements greater than pivot are on the right side of the pivot.
# * **APPLICATIONS**
#  * Quicksort algorithm is used when
#     * the programming language is good for recursion
#     * time complexity matters
#     * space complexity matters

# %%
def partition(array, start, end):
    pivot = array[start]
    low = start + 1
    high = end

    while True:
       
        while low <= high and array[high] >= pivot:
            high = high - 1

      
        while low <= high and array[low] <= pivot:
            low = low + 1

        
        if low <= high:
            array[low], array[high] = array[high], array[low]
            
        else:
            
            break

    array[start], array[high] = array[high], array[start]

    return high


def quick_sort(array, start, end):
    if start >= end:
        return

    p = partition(array, start, end)
    quick_sort(array, start, p-1)
    quick_sort(array, p+1, end)

# %%
array = [29.98,9966,2.858667,41.3658,66.885,2.2859638,44.5555,78.65895,87.99999,19,31,76,58,88,83,97,12,21,44]

quick_sort(array, 0, len(array) - 1)
print(array)
# %timeit quick_sort(array, 0, len(array) - 1)
# Out:
# [2.2859638, 2.858667, 12, 19, 21, 29.98, 31, 41.3658, 44, 44.5555, 58, 66.885, 76, 78.65895, 83, 87.99999, 88, 97, 9966]
# 38.9 µs ± 2.3 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# #### HEAP SORT :

# %% [markdown]
# * Heap Sort is a popular and efficient sorting algorithm in computer programming.
# * Heap sort works by visualizing the elements of the array as a special kind of complete binary tree called a **HEAP**

# %% [markdown]
# * **APPLICATIONS**
# * Heap Sort Applications
#     * Systems concerned with security and embedded systems such as Linux Kernel use Heap Sort because of the O(n log n) upper bound on Heapsort's running time and constant O(1) upper bound on its auxiliary storage.
#     * EX: PRIORITY QUEUES

# %%
from heapq import heappop, heappush

def heap_sort(array):
    heap = []
    for element in array:
        heappush(heap, element)

    ordered = []

    # While we have elements left in the heap
    while heap:
        ordered.append(heappop(heap))

    return ordered

array = [13.000000067, 11.4956821, 12.9999989558855, 5.68579958, 26, 4.999989589589588, 17, 18, 24, 3.99999999999999]
print(heap_sort(array))
# %timeit heap_sort(array)
# Out:
# [3.99999999999999, 4.999989589589588, 5.68579958, 11.4956821, 12.9999989558855, 13.000000067, 17, 18, 24, 26]
# 3.81 µs ± 340 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# # 2. What Are the Benefits of Stacks?

# %% [markdown]
# * **STACK** : It is a type of datastructure which implements LAST IN FIRST OUT(LIFO) method.In this data structure data stored in STACKS i.e. linear data structure.

# %%
stack=[]
stack.append(10)
stack.append(12)
stack.append(14)
stack.append(16)
stack.append(18)
stack
# Out:
# [10, 12, 14, 16, 18]

# %%
stack.pop() ### in this the last element to append list is 16 and first element to exit is also 18.
# Out:
# 18

# %% [markdown]
# #### Benefits of STACKS :

# %% [markdown]
# * They’re very useful because they afford you constant time O(1) operations when inserting or removing from the front of a data structure.
# * One common use of a stack is in compilers, where a stack can be used to make sure that the brackets and parentheses in a code file are all balanced, i.e., have an opening and closing counterpart.
# * Stacks are also very useful in evaluating mathematical expressions.
# * The back button in a browser saves all the URLs you have visited previously in a **STACK**.
# * Stacks allows you to control how memory is allocated and deallocated.

# %% [markdown]
# # 3. What is the difference between a stack and a queue?

# %% [markdown]
# * STACK : It is a type of datastructure which implements LAST IN FIRST OUT(LIFO) method.In this data structure data stored in STACKS i.e. linear data structure.

# %% [markdown]
# * QUEUE : It is similar to stack but it implements FIRST IN FIRST OUT(FIFO) method. In this datastructure data stored in QUEUE.

# %%
stac=[]
stac.append(10)
stac.append(12)
stac.append(14)
stac.append(16)
stac.append(18)
stac
# Out:
# [10, 12, 14, 16, 18]

# %%
stac.append(20)

# %%
stac
# Out:
# [10, 12, 14, 16, 18, 20]

# %%
stac.pop()
# Out:
# 20

# %% [markdown]
# * The major difference is, Stack is only one end opened, so it follows the principle of Last in last out(LIFO), and the queue has both ends opened it follows First in first out principle(FIFO).
# * Insertion and deletion in **STACKS** takes place only from one end of the list called the top.But in a **QUEUE** takes place from the opposite ends of the list.
# * **Insertion and deletion** in **STACKS** using **push() and pop()** operation
# * **Insertion and deletion** in **QUEUE** using **enqueue() and dequeue** operation.
# * In STACKS we maintain only **one pointer** to access the list, called **the top**, which always points to the last element present in the list.
# * In QUEUES we maintain **two pointers to access the list**. The front pointer always points to the first element inserted in the list and the rear pointer always points to the last inserted element.
# * **Stack is used in solving problems works on recursion, whereas Queue is used in solving problems having sequential processing**.

# %% [markdown]
# # 4. What are the different forms of queues?

# %% [markdown]
# * QUEUE : It is similar to stack but it implements FIRST IN FIRST OUT(FIFO) method. In this datastructure data stored in QUEUE

# %% [markdown]
# * Different forms of Queues:
#   * Simple Queue
#   * Circular Queue
#   * Priority Queue
#   * Double Ended Queue

# %% [markdown]
# ##### **Simple Queue**:

# %% [markdown]
# * In a simple queue, insertion takes place at the rear and removal occurs at the front. It strictly follows the FIFO (First in First out) rule.

# %% [markdown]
# ##### **Circular Queue**:

# %% [markdown]
# * A circular queue is the extended version of a regular queue where the last element is connected to the first element. Thus forming a circle-like structure.
# * The circular queue solves the major limitation of the normal queue. In a normal queue, after a bit of insertion and deletion, there will be non-usable empty space i.e. indexes 0 and 1 can only be used after resetting the queue (deletion of all elements). This reduces the actual size of the queue.
# * **APPLICATIONS**:
#         * CPU scheduling
#         * Memory management
#         * Traffic Management

# %% [markdown]
# ###### **Priority Queue**:

# %% [markdown]
# * A priority queue is a special type of queue in which each element is associated with a priority value. And, elements are served on the basis of their priority. That is, higher priority elements are served first.
# * In a **queue**, the first-in-first-out rule is implemented whereas, in a **priority queue**, the values are removed on the basis of priority. The element with the highest priority is removed first.

# %% [markdown]
# * **APPLICATIONS** :
#     * Dijkstra's algorithm
#     * for implementing stack
#     * for load balancing and interrupt handling in an operating system
#     * for data compression in Huffman code

# %% [markdown]
# ##### Double Ended Queue :

# %% [markdown]
# * Deque or Double Ended Queue is a type of queue in which insertion and removal of elements can either be performed from the front or the rear. Thus, it does not follow FIFO rule (First In First Out).
# * Types of Deque
#     * Input Restricted Deque
#        * In this deque, input is restricted at a single end but allows deletion at both the ends.
#     * Output Restricted Deque
#         * In this deque, output is restricted at a single end but allows insertion at both the ends.

# %% [markdown]
# * **APPLICATIONS**:
#     * In undo operations on software.
#     * To store history in browsers.
#     * For implementing both stacks and queues.

# %% [markdown]
# # 5. Why should I use Stack or Queue data structures instead of Arrays or Lists, and when should I use them?

# %% [markdown]
# * STACKS and QUEUE help managing our data in more a particular way than arrays and lists.
# * Arrays and lists are random access. They are very flexible and also easily corruptible. If you want to manage your data as FIFO or LIFO it's best to use those, already implemented, collections.
# ##### More practically you should:
# * Use a queue when you want to get things out in the order that you put them in (FIFO)
# * Use a stack when you want to get things out in the reverse order than you put them in (LIFO)
# * Use a list when you want to get anything out i.e dyanamic array

# %% [markdown]
# * TIME COMPLEXITY:
# The complexity of enqueue and dequeue operations in a **QUEUE** and push and pop operations in **STACK** using an array is O(1) but for for **Arrays** it is constant O(1) and for **Linked Lists** it is linear O(n).

# %% [markdown]
# *  STACKS and QUEUE classes for tighter control of our data unlike an ARRAY,which  caters single datatype and LINKED LIST which require high memory allocation.

# %% [markdown]
# # 6. What is the significance of Stack being a recursive data structure?

# %% [markdown]
# * Stack is a LIFO data structure i.e. ( Last In First Out) and hence it is used to implement recursion."Recursion" is technique of solving any problem by calling same function again and again until some breaking (base) condition where recursion stops and it starts calculating the solution from there on.
#     * EX: Calculating factorial of a given number
# * In each recursive call, there is need to save the
#     * current values of parameters,
#     * local variables and
#     * the return address (the address where the control has to return from the call).
# * A function calls to another function, first its arguments, then the return address and finally space for local variables is pushed onto the stack.
# * The example of recursion as an application of stack is keeping books inside the drawer and the removing each book recursively
# * The High level Programming languages, such as Pascal , C etc. that provides support for recursion use stack for book keeping.

# %%
# Stack implementation in python


# Creating a stack
def create_stack():
    stack = []
    return stack


# Creating an empty stack
def check_empty(stack):
    return len(stack) == 0


# Adding items into the stack
def push(stack, item):
    stack.append(item)
    print("pushed item: " + item)


# Removing an element from the stack
def pop(stack):
    if (check_empty(stack)):
        return "stac is empty"

    return stack.pop()


stack = create_stack()
push(stack, str(1))
push(stack, str(2))
push(stack, str(3))
push(stack, str(4))
print("popped item: " + pop(stack))
print("stack after popping an element: " + str(stack))
# Out:
# pushed item: 1
# pushed item: 2
# pushed item: 3
# pushed item: 4
# popped item: 4
# stack after popping an element: ['1', '2', '3']

# %%
push(stack,str(6))
# Out:
# pushed item: 6

# %%
stack
# Out:
# ['1', '2', '3', '6']

# %%
stack.pop()
# Out:
# '6'

# %%
stack
# Out:
# ['1', '2', '3']
